# %%
from NBA_secrets import *
from flask import Flask, render_template, request
from sqlalchemy import create_engine
from nba_api.stats.static import teams
from nba_api.stats.endpoints import leaguegamefinder
import pandas as pd
import datetime
from NBA_secrets import *
from langchain.llms import OpenAI

database_type = database_type
dbapi = dbapi
endpoint = endpoint
user = user
password = password
port = port
database = database

DATABASE_URL = f"{database_type}+{dbapi}://{user}:{password}@{endpoint}:{port}/{database}"
engine = create_engine(DATABASE_URL)

# %%
games.iloc[400]
# Out:
# GAME_ID                 0028300401
# GAME_DATE               1984-01-10
# MATCHUP                  CLE @ MIL
# OUTCOME      Cleveland Cavaliers W
# MIN                            240
# PTS                            116
# FGM                             49
# FGA                             93
# FG_PCT                       0.527
# FG3M                             2
# FG3A                           3.0
# FG3_PCT                      0.667
# FTM                             16
# FTA                             17
# FT_PCT                       0.941
# OREB                          13.0
# DREB                          27.0
# REB                           40.0
# AST                             27
# STL                           17.0
# BLK                              3
# TOV                             13
# PF                              28
# AWAY_TEAM                      CLE
# HOME_TEAM                      MIL
# Name: 400, dtype: object

# %%
x = pd.read_sql("SELECT * FROM user_rankings_new", engine)

# %%
games = pd.read_sql("SELECT * FROM all_games_sorted", engine)

# %%
games['MATCHUP'].values[0].split('@')
# Out:
# ['NYK ', ' CLE']

# %%
teams = []
for i in games['MATCHUP']:
    matchup = i.split('@')
    matchup[0] = matchup[0].strip()
    matchup[1] = matchup[1].strip()
    teams.append([matchup[0],matchup[1]])

# %%
away = []
home = []
[away.append(team[0]) for team in teams]
[home.append(team[1]) for team in teams]
# Out:
# [None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
# ...

# %%
games['AWAY_TEAM'] = away
games['HOME_TEAM'] = home

# %%
nba_teams_all_time = {
    'AND': 'Anderson Packers',
    'ATL': 'Atlanta Hawks',
    'BAL': 'Baltimore Bullets',
    'BLB': 'Baltimore Bullets',
    'BOS': 'Boston Celtics',
    'BUF': 'Buffalo Braves',
    'CAP': 'Capital Bullets',
    'CHA': 'Charlotte Hornets',
    'CHP': 'Chicago Packers',
    'CHI': 'Chicago Bulls',
    'CHS': 'Chicago Stags',
    'CHT': 'Charlotte Bobcats',
    'CIN': 'Cincinnati Royals',
    'CLE': 'Cleveland Cavaliers',
    'CLR': 'Cleveland Rebels',
    'DAL': 'Dallas Mavericks',
    'DEN': 'Denver Nuggets',
    'DET': 'Detroit Pistons',
    'DNR': 'Denver Nuggets (NBL)',
    'FTW': 'Fort Wayne Pistons',
    'GOS': 'Golden State Warriors',
    'GSW': 'Golden State Warriors',
    'HOU': 'Houston Rockets',
    'IND': 'Indiana Pacers',
    'INO': 'Indianapolis Olympians',
    'KCK': 'Kansas City Kings',
    'KCO': 'Kansas City-Omaha Kings',
    'LAC': 'Los Angeles Clippers',
    'LAL': 'Los Angeles Lakers',
    'MEM': 'Memphis Grizzlies',
    'MIA': 'Miami Heat',
    'MIL': 'Milwaukee Bucks',
    'MIN': 'Minnesota Timberwolves',
    'MNL': 'Minneapolis Lakers',
    'NJN': 'New Jersey Nets',
    'NOH': 'New Orleans Hornets',
    'NOP': 'New Orleans Pelicans',
    'NOK': 'New Orleans/Oklahoma City Hornets',
    'NYK': 'New York Knicks',
    'OKC': 'Oklahoma City Thunder',
    'ORL': 'Orlando Magic',
    'PHI': 'Philadelphia 76ers',
    'PHL': 'Philadelphia 76ers',
    'PHW': 'Philadelphia Warriors',
    'PHX': 'Phoenix Suns',
    'POR': 'Portland Trail Blazers',
    'PRO': 'Providence Steamrollers',
    'ROC': 'Rochester Royals',
    'SAC': 'Sacramento Kings',
    'SDC': 'San Diego Clippers',
    'SDR': 'San Diego Rockets',
    'SEA': 'Seattle SuperSonics',
    'SAS': 'San Antonio Spurs',
    'SAN': 'San Antonio Spurs',
    'SHE': 'Sheboygan Red Skins',
    'STB': 'St. Louis Bombers',
    'STL': 'St. Louis Hawks',
    'SYR': 'Syracuse Nationals',
    'TOR': 'Toronto Raptors',
    'TRI': 'Tri-Cities Blackhawks',
    'UTA': 'Utah Jazz',
    'UTH': 'Utah Jazz',
    'VAN': 'Vancouver Grizzlies',
    'WAS': 'Washington Wizards',
    'WSB': 'Washington Bullets',
    'WSC': 'Washington Capitols',
    'WAT': 'Waterloo Hawks'
}

# %%
nba_teams_all_time = {
    'AND': 'Anderson Packers',
    'ATL': 'Atlanta Hawks',
    'BAL': 'Baltimore Bullets',
    'BLB': 'Baltimore Bullets',
    'BOS': 'Boston Celtics',
    'BUF': 'Buffalo Braves',
    'CAP': 'Capital Bullets',
    'CHA': 'Charlotte Hornets',
    'CHP': 'Chicago Packers',
    'CHI': 'Chicago Bulls',
    'CHS': 'Chicago Stags',
    'CHT': 'Charlotte Bobcats',
    'CIN': 'Cincinnati Royals',
    'CLE': 'Cleveland Cavaliers',
    'CLR': 'Cleveland Rebels',
    'DAL': 'Dallas Mavericks',
    'DEN': 'Denver Nuggets',
    'DET': 'Detroit Pistons',
    'DNR': 'Denver Nuggets (NBL)',
    'FTW': 'Fort Wayne Pistons',
    'GOS': 'Golden State Warriors',
    'GSW': 'Golden State Warriors',
    'HOU': 'Houston Rockets',
    'IND': 'Indiana Pacers',
    'INO': 'Indianapolis Olympians',
    'KCK': 'Kansas City Kings',
    'KCO': 'Kansas City-Omaha Kings',
    'LAC': 'Los Angeles Clippers',
    'LAL': 'Los Angeles Lakers',
    'MEM': 'Memphis Grizzlies',
    'MIA': 'Miami Heat',
    'MIL': 'Milwaukee Bucks',
    'MIN': 'Minnesota Timberwolves',
    'MNL': 'Minneapolis Lakers',
    'NJN': 'New Jersey Nets',
    'NOH': 'New Orleans Hornets',
    'NOP': 'New Orleans Pelicans',
    'NOK': 'New Orleans/Oklahoma City Hornets',
    'NYK': 'New York Knicks',
    'OKC': 'Oklahoma City Thunder',
    'ORL': 'Orlando Magic',
    'PHI': 'Philadelphia 76ers',
    'PHL': 'Philadelphia 76ers',
    'PHW': 'Philadelphia Warriors',
    'PHX': 'Phoenix Suns',
    'POR': 'Portland Trail Blazers',
    'PRO': 'Providence Steamrollers',
    'ROC': 'Rochester Royals',
    'SDC': 'San Diego Clippers',
    'SDR': 'San Diego Rockets',
    'SEA': 'Seattle SuperSonics',
    'SAS': 'San Antonio Spurs',
    'SAN': 'San Antonio Spurs',
    'SHE': 'Sheboygan Red Skins',
    'STB': 'St. Louis Bombers',
    'STL': 'St. Louis Hawks',
    'SYR': 'Syracuse Nationals',
    'TOR': 'Toronto Raptors',
    'TRI': 'Tri-Cities Blackhawks',
    'UTA': 'Utah Jazz',
    'UTH': 'Utah Jazz',
    'VAN': 'Vancouver Grizzlies',
    'WAS': 'Washington Wizards',
    'WSB': 'Washington Bullets',
    'WSC': 'Washington Capitols',
    'WAT': 'Waterloo Hawks'
}

# %%
nba_teams_all_time = {
    'AND': 'Anderson Packers',
    'ATL': 'Atlanta Hawks',
    'BAL': 'Baltimore Bullets',
    'BAR': 'Baltimore Bullets',
    'BLB': 'Baltimore Bullets',
    'BOS': 'Boston Celtics',
    'BUF': 'Buffalo Braves',
    'CAP': 'Capital Bullets',
    'CHA': 'Charlotte Hornets',
    'CHH': 'Charlotte Hornets',
    'CHP': 'Chicago Packers',
    'CHI': 'Chicago Bulls',
    'CHS': 'Chicago Stags',
    'CHT': 'Charlotte Bobcats',
    'CIN': 'Cincinnati Royals',
    'CLE': 'Cleveland Cavaliers',
    'CLR': 'Cleveland Rebels',
    'DAL': 'Dallas Mavericks',
    'DEN': 'Denver Nuggets',
    'DET': 'Detroit Pistons',
    'DNR': 'Denver Nuggets (NBL)',
    'FTW': 'Fort Wayne Pistons',
    'GOS': 'Golden State Warriors',
    'GSW': 'Golden State Warriors',
    'HOU': 'Houston Rockets',
    'IND': 'Indiana Pacers',
    'INO': 'Indianapolis Olympians',
    'KCK': 'Kansas City Kings',
    'KCO': 'Kansas City-Omaha Kings',
    'LAC': 'Los Angeles Clippers',
    'LAL': 'Los Angeles Lakers',
    'MEM': 'Memphis Grizzlies',
    'MIA': 'Miami Heat',
    'MIL': 'Milwaukee Bucks',
    'MIN': 'Minnesota Timberwolves',
    'MNL': 'Minneapolis Lakers',
    'NJN': 'New Jersey Nets',
    'NOH': 'New Orleans Hornets',
    'NOP': 'New Orleans Pelicans',
    'NOK': 'New Orleans/Oklahoma City Hornets',
    'NYK': 'New York Knicks',
    'OKC': 'Oklahoma City Thunder',
    'ORL': 'Orlando Magic',
    'PHI': 'Philadelphia 76ers',
    'PHL': 'Philadelphia 76ers',
    'PHW': 'Philadelphia Warriors',
    'PHX': 'Phoenix Suns',
    'POR': 'Portland Trail Blazers',
    'PRO': 'Providence Steamrollers',
    'ROC': 'Rochester Royals',
    'SAC': 'Sacramento Kings',
    'SDC': 'San Diego Clippers',
    'SDR': 'San Diego Rockets',
    'SEA': 'Seattle SuperSonics',
    'SAS': 'San Antonio Spurs',
    'SAN': 'San Antonio Spurs',
    'SHE': 'Sheboygan Red Skins',
    'STB': 'St. Louis Bombers',
    'STL': 'St. Louis Hawks',
    'SYR': 'Syracuse Nationals',
    'TOR': 'Toronto Raptors',
    'TRI': 'Tri-Cities Blackhawks',
    'UTA': 'Utah Jazz',
    'UTH': 'Utah Jazz',
    'VAN': 'Vancouver Grizzlies',
    'WAS': 'Washington Wizards',
    'WSB': 'Washington Bullets',
    'WSC': 'Washington Capitols',
    'WAT': 'Waterloo Hawks'
}

# %%
games[games['HOME_TEAM'] == 'LRO']
# Out:
#           GAME_ID   GAME_DATE    MATCHUP            OUTCOME  MIN  PTS  FGM  \
# 28442  0010700003  2007-10-07  TOR @ LRO  Toronto Raptors W  240   93   29
#
#        FGA  FG_PCT  FG3M  ...  OREB  DREB   REB  AST  STL  BLK  TOV  PF  \
# 28442   68   0.426     6  ...   7.0  32.0  39.0   17  4.0    0   15  26
#
#        AWAY_TEAM  HOME_TEAM
# 28442        TOR        LRO
#
# [1 rows x 25 columns]

# %%
matchups = []

for i in games['MATCHUP']:
    matchup = i.split('@')
    matchup[0] = matchup[0].strip()
    matchup[1] = matchup[1].strip()
    away_team = nba_teams_all_time[matchup[0]]
    home_team = nba_teams_all_time[matchup[1]]
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[97], line 8
#       6 matchup[1] = matchup[1].strip()
#       7 away_team = nba_teams_all_time[matchup[0]]
# ----> 8 home_team = nba_teams_all_time[matchup[1]]
#
# KeyError: 'LRO'

# %%
count = 0
out_of_bounds =[]
for i, j in zip(games['AWAY_TEAM'], games['HOME_TEAM']):
    if i not in list(nba_teams_all_time.keys()) or j not in list(nba_teams_all_time.keys()):
        out_of_bounds.append(count)
    count+=1

# %%
out_of_bounds
# Out:
# [28431,
#  28437,
#  28445,
#  28446,
#  31347,
#  31358,
#  31394,
#  32830,
#  32837,
#  32864,
#  32868,
#  35395,
#  35399,
#  35401,
#  35406,
#  35412,
#  35418,
#  35429,
#  35462,
#  35464,
#  35469,
#  35471,
#  35495,
#  35499,
#  35508,
#  35518,
#  35520,
#  35549,
#  35597,
#  35608,
#  35619,
#  35636,
#  35652,
#  35666,
#  35676,
#  35698,
#  35711,
#  35717,
#  35731,
#  35747,
#  35754,
#  35762,
#  35780,
#  35790,
#  35803,
#  35821,
#  35842,
#  35850,
#  35853,
#  35874,
#  35879,
#  35904,
#  35907,
#  35939,
#  35945,
#  35947,
#  35964,
#  35985,
#  36002,
#  36014,
#  36021,
#  36042,
#  36066,
#  36077,
#  36092,
#  36101,
#  36108,
#  36135,
#  36156,
#  36166,
#  36182,
#  36194,
#  36206,
#  36235,
#  36239,
#  36250,
#  36267,
#  36281,
#  36291,
#  36301,
#  36308,
#  36328,
#  36354,
#  36377,
#  36384,
#  36414,
#  36434,
#  36447,
#  36452,
#  36490,
#  36493,
#  36507,
#  36533,
#  36536,
#  36562,
#  36575,
#  36581,
#  36605,
#  36613,
#  36629,
# ...

# %%
games.iloc[28434]
# Out:
# GAME_ID        0010700006
# GAME_DATE      2007-10-08
# MATCHUP         MIA @ DET
# OUTCOME      Miami Heat L
# MIN                   240
# PTS                    86
# FGM                    31
# FGA                    77
# FG_PCT              0.403
# FG3M                    7
# FG3A                 18.0
# FG3_PCT             0.389
# FTM                    17
# FTA                    23
# FT_PCT              0.739
# OREB                 10.0
# DREB                 25.0
# REB                  35.0
# AST                    22
# STL                   7.0
# BLK                     6
# TOV                    16
# PF                     29
# AWAY_TEAM             MIA
# HOME_TEAM             DET
# Name: 28443, dtype: object

# %%
out

# %%
out_of_bounds[0]
# Out:
# 28433

# %%
games = games.drop(28434)

# %%
for i in out_of_bounds:
    games = games.drop(int(i))
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[101], line 2
#       1 for i in out_of_bounds:
# ----> 2     games = games.drop(int(i))
#
# File /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/pandas/util/_decorators.py:331, in deprecate_nonkeyword_arguments.<locals>.decorate.<locals>.wrapper(*args, **kwargs)
#     325 if len(args) > num_allow_args:
#     326     warnings.warn(
#     327         msg.format(arguments=_format_argument_list(allow_args)),
#     328         FutureWarning,
#     329         stacklevel=find_stack_level(),
#     330     )
# --> 331 return func(*args, **kwargs)
#
# File /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/pandas/core/frame.py:5399, in DataFrame.drop(self, labels, axis, index, columns, level, inplace, errors)
# ...

# %%
games.shape
# Out:
# (51660, 25)

# %%
games = games.drop(28440)

# %%
games[games['HOME_TEAM'] == 'EPT']
# Out:
#           GAME_ID   GAME_DATE    MATCHUP                   OUTCOME  MIN  PTS  \
# 28440  0010700002  2007-10-06  MIN @ EPT  Minnesota Timberwolves W  239   84
#
#        FGM  FGA  FG_PCT  FG3M  ...  OREB  DREB   REB  AST  STL  BLK  TOV  PF  \
# 28440   29   86   0.337     8  ...  24.0  44.0  68.0   16  5.0    4   18  28
#
#        AWAY_TEAM  HOME_TEAM
# 28440        MIN        EPT
#
# [1 rows x 25 columns]

# %%
all_games_sorted

# %%
games.columns
# Out:
# Index(['GAME_ID', 'GAME_DATE', 'MATCHUP', 'OUTCOME', 'MIN', 'PTS', 'FGM',
#        'FGA', 'FG_PCT', 'FG3M', 'FG3A', 'FG3_PCT', 'FTM', 'FTA', 'FT_PCT',
#        'OREB', 'DREB', 'REB', 'AST', 'STL', 'BLK', 'TOV', 'PF', 'AWAY_TEAM',
#        'HOME_TEAM'],
#       dtype='object')

# %%
games.to_sql("all_games_sorted", engine, index=False, if_exists='replace')
# Out:
# 643

# %%
y = pd.read_sql("SELECT * FROM all_games_sorted", engine)

# %%
y
# Out:
#           GAME_ID   GAME_DATE    MATCHUP                   OUTCOME  MIN  PTS  \
# 0      0028300008  1983-10-28  NYK @ CLE         New York Knicks W  240  121
# 1      0028300005  1983-10-28  ATL @ NJN           Atlanta Hawks L  240  108
# 2      0028300006  1983-10-28  BOS @ DET          Boston Celtics L  240  121
# 3      0028300007  1983-10-28  SDC @ POR      San Diego Clippers L  240   93
# 4      0028300004  1983-10-28  GOS @ SEA   Golden State Warriors W  240  110
# ...           ...         ...        ...                       ...  ...  ...
# 52859  0042300303  2024-05-25  BOS @ IND          Boston Celtics W  239  114
# 52860  0042300313  2024-05-26  MIN @ DAL  Minnesota Timberwolves L  239  107
# 52861  0042300304  2024-05-27  BOS @ IND          Boston Celtics W  240  105
# 52862  0042300314  2024-05-28  MIN @ DAL  Minnesota Timberwolves W  240  105
# 52863  0042300315  2024-05-30  DAL @ MIN        Dallas Mavericks W  240  124
#
# ...
